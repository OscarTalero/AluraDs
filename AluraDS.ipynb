# %% [markdown]
# <a href="https://colab.research.google.com/github/OscarTalero/AluraDs/blob/main/AluraDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {'Baños': 'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7597         Casa                       Casa en venta en Bosa             4
# 1277  Apartamento            Apartamento en venta en Engativa             2
# 9288  Apartamento            Apartamento en venta en Galerias             1
# 7216  Apartamento  Apartamento en venta en Zona Noroccidental             1
# 3638  Apartamento  Apartamento en venta en Zona Noroccidental             4
# 8316         Casa              Casa en venta en Villa Alsacia             3
# 2259  Apartamento     Apartamento en venta en Chico Reservado             4
# 4046  Apartamento             Apartamento en venta en Kennedy             3
# 5226  Apartamento                Apartamento en venta en Bosa             3
# 9241         Casa             Casa en venta en Barrios Unidos             5
#
#       Banos  Area              Barrio                                 UPZ  \
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
(inmuebles.Barrio == 'Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == 'Chico Reservado'))
# Out:
# 225

# %%
chico_reservado = inmuebles[(inmuebles.Barrio == 'Chico Reservado')]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# **Desafío**
#
# 1. Promedio de área de todos los inmuebles en los barrios en el dataset. El top 10.
#
# 2. Consultar otros datos estadísticos, conteo, mediana, valores mínimo y máximo.

# %%
inmuebles_barrios = inmuebles.groupby('Barrio')
promedio_area_barrios = inmuebles_barrios.Area.mean()
promedio_area_barrios
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# Top 10 de los barrios con mayor area promedio

# %%
promedio_area_barrios.sort_values(ascending=False).head(10)
# Out:
# Barrio
# Modelia                  4316.750000
# Libertador                642.000000
# Bosa Piamonte             400.000000
# La Soledad                378.625000
# Restrepo                  336.500000
# Santa Librada             328.000000
# Las Ferias                320.000000
# Santa Ana                 309.375000
# Veraguas                  302.666667
# Bellavista Occidental     286.200000
# Name: Area, dtype: float64

# %% [markdown]
# Top 10 de la Mediana del area de los barrios

# %%
mediana_area_barrios = inmuebles_barrios.Area.median()
mediana_area_barrios.sort_values(ascending=False).head(10)
# Out:
# Barrio
# Libertador       642.0
# Bosa Piamonte    400.0
# Restrepo         365.0
# Santa Librada    328.0
# Las Ferias       320.0
# Las Delicias     280.0
# Boyaca           278.0
# Roma             260.0
# Chico Navarra    259.0
# Santa Ana        245.0
# Name: Area, dtype: float64

# %% [markdown]
# Top 10 del area Maxima de los barrios

# %%
maximo_area_barrios = inmuebles_barrios.Area.max()
maximo_area_barrios.sort_values(ascending=False).head(10)
# Out:
# Barrio
# Modelia               166243
# Chapinero              15920
# Barrios Unidos          8884
# Usaquén                 6364
# Zona Noroccidental      5458
# Engativa                4600
# Teusaquillo             3500
# Suba                    1996
# Las Nieves              1800
# El Chicó                1550
# Name: Area, dtype: int64

# %% [markdown]
# Top 10 del area Minima de los barrios

# %%
minimo_area_barrios = inmuebles_barrios.Area.min()
minimo_area_barrios.sort_values(ascending=True).head(10)
# Out:
# Barrio
# San Cristobal          2
# Rafael Uribe Uribe     5
# Chapinero             15
# Zona Noroccidental    16
# Puente Largo          16
# Las Nieves            16
# San Patricio          19
# Engativa              21
# Los Mártires          22
# Teusaquillo           22
# Name: Area, dtype: int64

# %% [markdown]
# Otros datos estadisticos

# %%
inmuebles_barrios.describe()
# Out:
#                    Habitaciones                                           \
#                           count      mean       std  min  25%  50%   75%
# Barrio
# Alameda                     1.0  3.000000       NaN  3.0  3.0  3.0  3.00
# Alhambra                   17.0  3.000000  0.866025  1.0  3.0  3.0  4.00
# Andes Norte                 7.0  3.000000  1.000000  1.0  3.0  3.0  3.50
# Antonio Nariño             48.0  4.312500  3.102204  1.0  3.0  3.0  5.00
# Barrancas                  15.0  2.866667  0.351866  2.0  3.0  3.0  3.00
# ...                         ...       ...       ...  ...  ...  ...   ...
# Villa Maria                13.0  4.692308  0.751068  3.0  5.0  5.0  5.00
# Villas De Granada          22.0  3.454545  0.857864  3.0  3.0  3.0  3.75
# Villemar                   18.0  2.944444  1.161754  2.0  2.0  3.0  3.00
# Zona Franca                 1.0  2.000000       NaN  2.0  2.0  2.0  2.00
# Zona Noroccidental        877.0  3.167617  1.731510  1.0  3.0  3.0  3.00
#
# ...

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %% [markdown]
# Oferta por tipo de inmueble por barrios

# %%
inmuebles_tipo = inmuebles.groupby(['Barrio', 'Tipo'])
inmuebles_tipo.size()
# Out:
# Barrio              Tipo
# Alameda             Apartamento              1
# Alhambra            Apartamento              9
#                     Casa                     8
# Andes Norte         Apartamento              5
#                     Casa                     2
#                                           ...
# Zona Noroccidental  Apartamento            635
#                     Casa                   233
#                     Finca                    2
#                     Local                    2
#                     Oficina/Consultorio      5
# Length: 303, dtype: int64
